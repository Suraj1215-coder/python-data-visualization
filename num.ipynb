# %%
x =10
y =x
print(id(x))
print(id(y))
# Out:
# 140716554904984
# 140716554904984

# %%
a = 10
b = 20
a,b = b,a

# %%
print(a)
print(b)
# Out:
# 20
# 10

# %%
num = [1,2,3,4,5]
a, *b = num
print(a)
print(b)
# Out:
# 1
# [2, 3, 4, 5]

# %%
*a,b = num
print(a,b)
# Out:
# [1, 2, 3, 4] 5

# %%
*a,b,c = num
print(a)
print(b)
print(c)
# Out:
# [1, 2, 3]
# 4
# 5

# %%
student = ("surya", 20 , "CSE")
name , age , dept = student
print(name , age ,dept)
# Out:
# surya 20 CSE
